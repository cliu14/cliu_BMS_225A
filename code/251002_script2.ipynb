# %% [markdown]
# <a href="https://colab.research.google.com/github/cliu14/cliu_BMS_225A/blob/main/code/251002_script2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print("BMS 225A")
# Out:
# BMS 225A

# %% [markdown]
# # Task
# Create a simple logistic regression curve with sample data.

# %% [markdown]
# ## Generate sample data
#
# ### Subtask:
# Create synthetic data for a binary classification problem.

# %% [markdown]
# **Reasoning**:
# Generate synthetic data for a binary classification problem with noise and create a DataFrame.

# %%
np.random.seed(42) # for reproducibility
n_samples = 100
X = np.random.rand(n_samples, 1) * 10 # Generate x values between 0 and 10
y = (X > 5).astype(int) # Create binary labels based on a threshold

# Add some noise to the labels
noise_level = 0.1
noise_indices = np.random.choice(n_samples, int(n_samples * noise_level), replace=False)
y[noise_indices] = 1 - y[noise_indices]

df = pd.DataFrame({'x': X.flatten(), 'y': y.flatten()})
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-58709540.py in <cell line: 0>()
#       9 y[noise_indices] = 1 - y[noise_indices]
#      10
# ---> 11 df = pd.DataFrame({'x': X.flatten(), 'y': y.flatten()})
#      12 display(df.head())
#
# NameError: name 'pd' is not defined

# %% [markdown]
# **Reasoning**:
# The previous code block failed because `pd` was not defined. Although `pd` was imported in a previous cell, the current execution environment does not have access to it. The fix is to re-import pandas within the current code block.

# %%
import pandas as pd
np.random.seed(42) # for reproducibility
n_samples = 100
X = np.random.rand(n_samples, 1) * 10 # Generate x values between 0 and 10
y = (X > 5).astype(int) # Create binary labels based on a threshold

# Add some noise to the labels
noise_level = 0.1
noise_indices = np.random.choice(n_samples, int(n_samples * noise_level), replace=False)
y[noise_indices] = 1 - y[noise_indices]

df = pd.DataFrame({'x': X.flatten(), 'y': y.flatten()})
display(df.head())
# Out:
#           x  y
# 0  3.745401  0
# 1  9.507143  1
# 2  7.319939  1
# 3  5.986585  1
# 4  1.560186  0

# %% [markdown]
# ## Fit logistic regression model
#
# ### Subtask:
# Train a logistic regression model on the generated data.

# %% [markdown]
# **Reasoning**:
# Train a logistic regression model on the generated data.

# %%
from sklearn.linear_model import LogisticRegression

# Instantiate a LogisticRegression model
model = LogisticRegression()

# Reshape the feature data to be a 2D array
X = df[['x']]
y = df['y']

# Fit the model to the data
model.fit(X, y)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Plot the data and the curve
#
# ### Subtask:
# Visualize the sample data and the fitted logistic regression curve.

# %% [markdown]
# **Reasoning**:
# Visualize the sample data and the fitted logistic regression curve.

# %%
# Create a scatter plot of the original data
plt.scatter(df['x'], df['y'], label='Sample Data', alpha=0.6)

# Generate a range of x values for the curve
x_values = np.linspace(df['x'].min(), df['x'].max(), 300).reshape(-1, 1)

# Calculate predicted probabilities
y_prob = model.predict_proba(x_values)[:, 1]

# Plot the logistic regression curve
plt.plot(x_values, y_prob, color='red', label='Logistic Regression Curve')

# Add labels and title
plt.xlabel('X')
plt.ylabel('Probability')
plt.title('Logistic Regression Curve')

# Add legend
plt.legend()

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The analysis successfully generated 100 synthetic data points with a single feature 'x' and a binary target variable 'y', including a 10% noise level in the labels.
# *   A logistic regression model was successfully trained on the generated data.
# *   The final visualization effectively displays the sample data points and the fitted logistic regression curve, showing the relationship between the 'x' values and the predicted probability of the target variable being 1.
#
# ### Insights or Next Steps
#
# *   The logistic regression curve visually represents the model's prediction of the probability of the positive class based on the input feature.
# *   Further analysis could involve evaluating the model's performance using metrics like accuracy, precision, or recall, and exploring the model's coefficients to understand the relationship between the feature and the target variable.
